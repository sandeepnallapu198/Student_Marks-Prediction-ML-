# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
SM = pd.read_csv("C:\\AI(ml&dl)\\jupiter(machine learning)\\Projetcs(ML)\\12_ExamMarkPrediction_LINEARREGRESSION_MULTIPLEVARIABLES\\data.csv")
SM.head()
# Out:
#    hours  age  internet  marks
# 0   6.83   15         1  78.50
# 1   6.56   16         0  76.74
# 2    NaN   17         1  78.68
# 3   5.67   18         0  71.82
# 4   8.67   19         1  84.19

# %%
SM.shape
# Out:
# (201, 4)

# %%
SM.duplicated().sum()
# Out:
# 0

# %%
SM.describe()
# Out:
#             hours         age    internet       marks
# count  196.000000  201.000000  201.000000  201.000000
# mean     6.981429   17.467662    0.552239   77.951244
# std      1.266266    1.720523    0.498505    4.919626
# min      4.150000   15.000000    0.000000   68.570000
# 25%      5.757500   16.000000    0.000000   73.400000
# 50%      7.110000   17.000000    1.000000   77.770000
# 75%      8.082500   19.000000    1.000000   82.300000
# max      8.990000   20.000000    1.000000   86.990000

# %%
SM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   hours     196 non-null    float64
#  1   age       201 non-null    int64
#  2   internet  201 non-null    int64
#  3   marks     201 non-null    float64
# dtypes: float64(2), int64(2)
# memory usage: 6.4 KB

# %%
SM.isna().sum()
# Out:
# hours       5
# age         0
# internet    0
# marks       0
# dtype: int64

# %%
SM.hours = SM.hours.fillna(SM.hours.median())

# %%
SM.isna().sum()
# Out:
# hours       0
# age         0
# internet    0
# marks       0
# dtype: int64

# %%
sns.pairplot(SM,hue = 'marks')
plt.show()

# %%
sns.heatmap(SM.corr(),annot = True)
plt.show()

# %%
x = SM.iloc[:,:-1].values
y = SM.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.3,random_state = 0)
x_train.shape
# Out:
# (140, 3)

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(x_train,y_train)
pred=LR.predict(x_test)
print(r2_score(y_test,pred)*100)
# Out:
# 95.15254244514696

# %%
a= [[6.56,16,0]]
result=LR.predict(a)
print(result)
# Out:
# [76.56263256]
